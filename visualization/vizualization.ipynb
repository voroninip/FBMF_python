# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt 
import seaborn as sns 

import warnings
warnings.filterwarnings('ignore')

# Graphics in retina format are more sharp and legible
# %config InlineBackend.figure_format = 'retina'

# %%
df = pd.read_csv('flight_delays.csv')
df
# Out:
#       Month DayofMonth DayOfWeek  DepTime UniqueCarrier Origin Dest  Distance  \
# 0       c-8       c-21       c-7     1934            AA    ATL  DFW       732
# 1       c-4       c-20       c-3     1548            US    PIT  MCO       834
# 2       c-9        c-2       c-5     1422            XE    RDU  CLE       416
# 3      c-11       c-25       c-6     1015            OO    DEN  MEM       872
# 4      c-10        c-7       c-6     1828            WN    MDW  OMA       423
# ...     ...        ...       ...      ...           ...    ...  ...       ...
# 99995   c-5        c-4       c-3     1618            OO    SFO  RDD       199
# 99996   c-1       c-18       c-3      804            CO    EWR  DAB       884
# 99997   c-1       c-24       c-2     1901            NW    DTW  IAH      1076
# 99998   c-4       c-27       c-4     1515            MQ    DFW  GGG       140
# 99999  c-11       c-17       c-4     1800            WN    SEA  SMF       605
#
#       dep_delayed_15min
# 0                     N
# 1                     N
# 2                     N
# 3                     N
# 4                     Y
# ...                 ...
# 99995                 N
# 99996                 N
# 99997                 N
# 99998                 N
# 99999                 N
#
# [100000 rows x 9 columns]

# %%
def trunc_str_int(s):
    return int(s[2::])


def bool_int(S):
    return 1 if S == 'Y' else 0


df = df.rename(columns={"dep_delayed_15min": "Delayed"})
df['Delayed'] = df['Delayed'].apply(bool_int)
df['DayofMonth'] = df['DayofMonth'].apply(trunc_str_int)
df['DayOfWeek'] = df['DayOfWeek'].apply(trunc_str_int)
df['Month'] = df['Month'].apply(trunc_str_int)
df
# Out:
#        Month  DayofMonth  DayOfWeek  DepTime UniqueCarrier Origin Dest  \
# 0          8          21          7     1934            AA    ATL  DFW
# 1          4          20          3     1548            US    PIT  MCO
# 2          9           2          5     1422            XE    RDU  CLE
# 3         11          25          6     1015            OO    DEN  MEM
# 4         10           7          6     1828            WN    MDW  OMA
# ...      ...         ...        ...      ...           ...    ...  ...
# 99995      5           4          3     1618            OO    SFO  RDD
# 99996      1          18          3      804            CO    EWR  DAB
# 99997      1          24          2     1901            NW    DTW  IAH
# 99998      4          27          4     1515            MQ    DFW  GGG
# 99999     11          17          4     1800            WN    SEA  SMF
#
#        Distance  Delayed
# 0           732        0
# 1           834        0
# 2           416        0
# 3           872        0
# 4           423        1
# ...         ...      ...
# 99995       199        0
# 99996       884        0
# 99997      1076        0
# 99998       140        0
# 99999       605        0
#
# [100000 rows x 9 columns]

# %% [markdown]
# ### 1. Доля всех задержек ко всем вылетам

# %%
print('Доля задержек: ', df['Delayed'].sum() / len(df))
# Out:
# Доля задержек:  0.19044

# %%
plt.pie(df.groupby('Delayed')['Delayed'].count(), labels=['not delayed', 'delayed'])
plt.title("Delay statistics")
plt.show()

# %% [markdown]
# ### 2. Найти зависимость количества задержек от длины пути, который предстоит пролететь самолету

# %%
df.head(10)
# Out:
#    Month  DayofMonth  DayOfWeek  DepTime UniqueCarrier Origin Dest  Distance  \
# 0      8          21          7     1934            AA    ATL  DFW       732
# 1      4          20          3     1548            US    PIT  MCO       834
# 2      9           2          5     1422            XE    RDU  CLE       416
# 3     11          25          6     1015            OO    DEN  MEM       872
# 4     10           7          6     1828            WN    MDW  OMA       423
# 5      8           3          4     1918            NW    MEM  MCO       683
# 6      1          27          4      754            DL    PBI  LGA      1035
# 7      4          29          6      635            OH    MSP  CVG       596
# 8      7          28          5      735            AA    ONT  DFW      1189
# 9      6          20          2     2029            OO    DEN  PSC       853
#
#    Delayed
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
# 5        0
# 6        0
# 7        0
# 8        0
# 9        0

# %%
A = df.groupby('Distance')['Delayed'].sum().reset_index()
sns.histplot(data=A, x='Distance', bins=50, color='blue')
plt.ylabel('Delays')
plt.show()

# %% [markdown]
# Видим, что с увеличением дальности полёта количество задержек рейсов уменьшается.

# %% [markdown]
# ### 3. Топ 5 направлений, для которых чаще всего происходят задержки

# %%
df.head(10)
# Out:
#    Month  DayofMonth  DayOfWeek  DepTime UniqueCarrier Origin Dest  Distance  \
# 0      8          21          7     1934            AA    ATL  DFW       732
# 1      4          20          3     1548            US    PIT  MCO       834
# 2      9           2          5     1422            XE    RDU  CLE       416
# 3     11          25          6     1015            OO    DEN  MEM       872
# 4     10           7          6     1828            WN    MDW  OMA       423
# 5      8           3          4     1918            NW    MEM  MCO       683
# 6      1          27          4      754            DL    PBI  LGA      1035
# 7      4          29          6      635            OH    MSP  CVG       596
# 8      7          28          5      735            AA    ONT  DFW      1189
# 9      6          20          2     2029            OO    DEN  PSC       853
#
#    Delayed
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
# 5        0
# 6        0
# 7        0
# 8        0
# 9        0

# %%
B = df.groupby('Dest')['Delayed'].sum().reset_index()
B = B.sort_values(by='Delayed', ascending=False)
B.head(5).style.hide()
# Out:
# <style type="text/css">
# </style>
# <table id="T_d3904">
#   <thead>
#     <tr>
#       <th id="T_d3904_level0_col0" class="col_heading level0 col0" >Dest</th>
#       <th id="T_d3904_level0_col1" class="col_heading level0 col1" >Delayed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d3904_row0_col0" class="data row0 col0" >ATL</td>
#       <td id="T_d3904_row0_col1" class="data row0 col1" >1281</td>
#     </tr>
#     <tr>
#       <td id="T_d3904_row1_col0" class="data row1 col0" >ORD</td>
#       <td id="T_d3904_row1_col1" class="data row1 col1" >1072</td>
#     </tr>
#     <tr>
#       <td id="T_d3904_row2_col0" class="data row2 col0" >DFW</td>
#       <td id="T_d3904_row2_col1" class="data row2 col1" >656</td>
#     </tr>
#     <tr>
#       <td id="T_d3904_row3_col0" class="data row3 col0" >EWR</td>
#       <td id="T_d3904_row3_col1" class="data row3 col1" >584</td>
#     </tr>
#     <tr>
#       <td id="T_d3904_row4_col0" class="data row4 col0" >LAX</td>
#       <td id="T_d3904_row4_col1" class="data row4 col1" >525</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.pie(B.head(5)['Delayed'], labels=B.head(5)['Dest'])
plt.title("Delays(Destination)")
plt.show()

# %% [markdown]
# ### 4. В какие времена года чаще всего происходят задержки рейсов

# %%
df.head(10)
# Out:
#    Month  DayofMonth  DayOfWeek  DepTime UniqueCarrier Origin Dest  Distance  \
# 0      8          21          7     1934            AA    ATL  DFW       732
# 1      4          20          3     1548            US    PIT  MCO       834
# 2      9           2          5     1422            XE    RDU  CLE       416
# 3     11          25          6     1015            OO    DEN  MEM       872
# 4     10           7          6     1828            WN    MDW  OMA       423
# 5      8           3          4     1918            NW    MEM  MCO       683
# 6      1          27          4      754            DL    PBI  LGA      1035
# 7      4          29          6      635            OH    MSP  CVG       596
# 8      7          28          5      735            AA    ONT  DFW      1189
# 9      6          20          2     2029            OO    DEN  PSC       853
#
#    Delayed
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
# 5        0
# 6        0
# 7        0
# 8        0
# 9        0

# %%
def season(q):
    if q == 1 or q == 2 or q == 12:
        return 'winter'
    if 3 <= q <= 5:
        return 'spring'
    if 6 <= q <= 8:
        return 'summer'
    if 9 <= q <= 11:
        return 'autumn'
    

df['Season'] = df['Month'].apply(season)
df
# Out:
#        Month  DayofMonth  DayOfWeek  DepTime UniqueCarrier Origin Dest  \
# 0          8          21          7     1934            AA    ATL  DFW
# 1          4          20          3     1548            US    PIT  MCO
# 2          9           2          5     1422            XE    RDU  CLE
# 3         11          25          6     1015            OO    DEN  MEM
# 4         10           7          6     1828            WN    MDW  OMA
# ...      ...         ...        ...      ...           ...    ...  ...
# 99995      5           4          3     1618            OO    SFO  RDD
# 99996      1          18          3      804            CO    EWR  DAB
# 99997      1          24          2     1901            NW    DTW  IAH
# 99998      4          27          4     1515            MQ    DFW  GGG
# 99999     11          17          4     1800            WN    SEA  SMF
#
#        Distance  Delayed  Season
# 0           732        0  summer
# 1           834        0  spring
# 2           416        0  autumn
# 3           872        0  autumn
# 4           423        1  autumn
# ...         ...      ...     ...
# 99995       199        0  spring
# 99996       884        0  winter
# 99997      1076        0  winter
# 99998       140        0  spring
# 99999       605        0  autumn
#
# [100000 rows x 10 columns]

# %%
C = df.groupby('Season')['Delayed'].sum().reset_index()
C = C.sort_values(by='Delayed', ascending=False)
C.style.hide()
# Out:
# <style type="text/css">
# </style>
# <table id="T_34384">
#   <thead>
#     <tr>
#       <th id="T_34384_level0_col0" class="col_heading level0 col0" >Season</th>
#       <th id="T_34384_level0_col1" class="col_heading level0 col1" >Delayed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_34384_row0_col0" class="data row0 col0" >summer</td>
#       <td id="T_34384_row0_col1" class="data row0 col1" >5723</td>
#     </tr>
#     <tr>
#       <td id="T_34384_row1_col0" class="data row1 col0" >winter</td>
#       <td id="T_34384_row1_col1" class="data row1 col1" >4849</td>
#     </tr>
#     <tr>
#       <td id="T_34384_row2_col0" class="data row2 col0" >spring</td>
#       <td id="T_34384_row2_col1" class="data row2 col1" >4295</td>
#     </tr>
#     <tr>
#       <td id="T_34384_row3_col0" class="data row3 col0" >autumn</td>
#       <td id="T_34384_row3_col1" class="data row3 col1" >4177</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.pie(data=C, x='Delayed', labels='Season')
plt.title("Delays(Season)")
plt.show()

# %% [markdown]
# ### 5. Найти топ 10 самых хороших перевозчиков, которые реже всего задерживают свои рейсы

# %%
df.head(10)
# Out:
#    Month  DayofMonth  DayOfWeek  DepTime UniqueCarrier Origin Dest  Distance  \
# 0      8          21          7     1934            AA    ATL  DFW       732
# 1      4          20          3     1548            US    PIT  MCO       834
# 2      9           2          5     1422            XE    RDU  CLE       416
# 3     11          25          6     1015            OO    DEN  MEM       872
# 4     10           7          6     1828            WN    MDW  OMA       423
# 5      8           3          4     1918            NW    MEM  MCO       683
# 6      1          27          4      754            DL    PBI  LGA      1035
# 7      4          29          6      635            OH    MSP  CVG       596
# 8      7          28          5      735            AA    ONT  DFW      1189
# 9      6          20          2     2029            OO    DEN  PSC       853
#
#    Delayed  Season
# 0        0  summer
# 1        0  spring
# 2        0  autumn
# 3        0  autumn
# 4        1  autumn
# 5        0  summer
# 6        0  winter
# 7        0  spring
# 8        0  summer
# 9        0  summer

# %%
D = df.groupby('UniqueCarrier')['Delayed'].sum().reset_index()
D = D.sort_values(by='Delayed', ascending=False)
D.head(10).style.hide()
# Out:
# <style type="text/css">
# </style>
# <table id="T_293e1">
#   <thead>
#     <tr>
#       <th id="T_293e1_level0_col0" class="col_heading level0 col0" >UniqueCarrier</th>
#       <th id="T_293e1_level0_col1" class="col_heading level0 col1" >Delayed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_293e1_row0_col0" class="data row0 col0" >WN</td>
#       <td id="T_293e1_row0_col1" class="data row0 col1" >3219</td>
#     </tr>
#     <tr>
#       <td id="T_293e1_row1_col0" class="data row1 col0" >AA</td>
#       <td id="T_293e1_row1_col1" class="data row1 col1" >1770</td>
#     </tr>
#     <tr>
#       <td id="T_293e1_row2_col0" class="data row2 col0" >MQ</td>
#       <td id="T_293e1_row2_col1" class="data row2 col1" >1448</td>
#     </tr>
#     <tr>
#       <td id="T_293e1_row3_col0" class="data row3 col0" >DL</td>
#       <td id="T_293e1_row3_col1" class="data row3 col1" >1373</td>
#     </tr>
#     <tr>
#       <td id="T_293e1_row4_col0" class="data row4 col0" >UA</td>
#       <td id="T_293e1_row4_col1" class="data row4 col1" >1322</td>
#     </tr>
#     <tr>
#       <td id="T_293e1_row5_col0" class="data row5 col0" >OO</td>
#       <td id="T_293e1_row5_col1" class="data row5 col1" >1277</td>
#     </tr>
#     <tr>
#       <td id="T_293e1_row6_col0" class="data row6 col0" >US</td>
#       <td id="T_293e1_row6_col1" class="data row6 col1" >1085</td>
#     </tr>
#     <tr>
#       <td id="T_293e1_row7_col0" class="data row7 col0" >EV</td>
#       <td id="T_293e1_row7_col1" class="data row7 col1" >1082</td>
#     </tr>
#     <tr>
#       <td id="T_293e1_row8_col0" class="data row8 col0" >NW</td>
#       <td id="T_293e1_row8_col1" class="data row8 col1" >1075</td>
#     </tr>
#     <tr>
#       <td id="T_293e1_row9_col0" class="data row9 col0" >XE</td>
#       <td id="T_293e1_row9_col1" class="data row9 col1" >1026</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.pie(data=D.head(10), x='Delayed', labels='UniqueCarrier')
plt.title("Delays(Carrier)")
plt.show()

# %% [markdown]
# ### 6. Найти топ 10 самых безответственных аэропортов, в которых чаще всего происходят задержки

# %%
df.head(10)
# Out:
#    Month  DayofMonth  DayOfWeek  DepTime UniqueCarrier Origin Dest  Distance  \
# 0      8          21          7     1934            AA    ATL  DFW       732
# 1      4          20          3     1548            US    PIT  MCO       834
# 2      9           2          5     1422            XE    RDU  CLE       416
# 3     11          25          6     1015            OO    DEN  MEM       872
# 4     10           7          6     1828            WN    MDW  OMA       423
# 5      8           3          4     1918            NW    MEM  MCO       683
# 6      1          27          4      754            DL    PBI  LGA      1035
# 7      4          29          6      635            OH    MSP  CVG       596
# 8      7          28          5      735            AA    ONT  DFW      1189
# 9      6          20          2     2029            OO    DEN  PSC       853
#
#    Delayed  Season
# 0        0  summer
# 1        0  spring
# 2        0  autumn
# 3        0  autumn
# 4        1  autumn
# 5        0  summer
# 6        0  winter
# 7        0  spring
# 8        0  summer
# 9        0  summer

# %%
E = df.groupby('Origin')['Delayed'].sum().reset_index()
E = E.sort_values(by='Delayed', ascending=False)
E.head(10).style.hide()
# Out:
# <style type="text/css">
# </style>
# <table id="T_07ed5">
#   <thead>
#     <tr>
#       <th id="T_07ed5_level0_col0" class="col_heading level0 col0" >Origin</th>
#       <th id="T_07ed5_level0_col1" class="col_heading level0 col1" >Delayed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_07ed5_row0_col0" class="data row0 col0" >ATL</td>
#       <td id="T_07ed5_row0_col1" class="data row0 col1" >1506</td>
#     </tr>
#     <tr>
#       <td id="T_07ed5_row1_col0" class="data row1 col0" >ORD</td>
#       <td id="T_07ed5_row1_col1" class="data row1 col1" >1254</td>
#     </tr>
#     <tr>
#       <td id="T_07ed5_row2_col0" class="data row2 col0" >DFW</td>
#       <td id="T_07ed5_row2_col1" class="data row2 col1" >902</td>
#     </tr>
#     <tr>
#       <td id="T_07ed5_row3_col0" class="data row3 col0" >DEN</td>
#       <td id="T_07ed5_row3_col1" class="data row3 col1" >575</td>
#     </tr>
#     <tr>
#       <td id="T_07ed5_row4_col0" class="data row4 col0" >LAX</td>
#       <td id="T_07ed5_row4_col1" class="data row4 col1" >552</td>
#     </tr>
#     <tr>
#       <td id="T_07ed5_row5_col0" class="data row5 col0" >LAS</td>
#       <td id="T_07ed5_row5_col1" class="data row5 col1" >546</td>
#     </tr>
#     <tr>
#       <td id="T_07ed5_row6_col0" class="data row6 col0" >EWR</td>
#       <td id="T_07ed5_row6_col1" class="data row6 col1" >538</td>
#     </tr>
#     <tr>
#       <td id="T_07ed5_row7_col0" class="data row7 col0" >IAH</td>
#       <td id="T_07ed5_row7_col1" class="data row7 col1" >492</td>
#     </tr>
#     <tr>
#       <td id="T_07ed5_row8_col0" class="data row8 col0" >PHX</td>
#       <td id="T_07ed5_row8_col1" class="data row8 col1" >491</td>
#     </tr>
#     <tr>
#       <td id="T_07ed5_row9_col0" class="data row9 col0" >DTW</td>
#       <td id="T_07ed5_row9_col1" class="data row9 col1" >401</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.pie(data=E.head(10), x='Delayed', labels='Origin')
plt.title("Delays(Origin)")
plt.show()

# %% [markdown]
# ### 7. Найти необычную зависимость количества задержек от имеющихся данных

# %%
df.head(10)
# Out:
#    Month  DayofMonth  DayOfWeek  DepTime UniqueCarrier Origin Dest  Distance  \
# 0      8          21          7     1934            AA    ATL  DFW       732
# 1      4          20          3     1548            US    PIT  MCO       834
# 2      9           2          5     1422            XE    RDU  CLE       416
# 3     11          25          6     1015            OO    DEN  MEM       872
# 4     10           7          6     1828            WN    MDW  OMA       423
# 5      8           3          4     1918            NW    MEM  MCO       683
# 6      1          27          4      754            DL    PBI  LGA      1035
# 7      4          29          6      635            OH    MSP  CVG       596
# 8      7          28          5      735            AA    ONT  DFW      1189
# 9      6          20          2     2029            OO    DEN  PSC       853
#
#    Delayed  Season
# 0        0  summer
# 1        0  spring
# 2        0  autumn
# 3        0  autumn
# 4        1  autumn
# 5        0  summer
# 6        0  winter
# 7        0  spring
# 8        0  summer
# 9        0  summer

# %%
F = df.groupby('Month')['Delayed'].sum().reset_index()
F = F.sort_values(by='Delayed', ascending=False)
F.head(10).style.hide()
# Out:
# <style type="text/css">
# </style>
# <table id="T_f6319">
#   <thead>
#     <tr>
#       <th id="T_f6319_level0_col0" class="col_heading level0 col0" >Month</th>
#       <th id="T_f6319_level0_col1" class="col_heading level0 col1" >Delayed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f6319_row0_col0" class="data row0 col0" >7</td>
#       <td id="T_f6319_row0_col1" class="data row0 col1" >2073</td>
#     </tr>
#     <tr>
#       <td id="T_f6319_row1_col0" class="data row1 col0" >12</td>
#       <td id="T_f6319_row1_col1" class="data row1 col1" >1994</td>
#     </tr>
#     <tr>
#       <td id="T_f6319_row2_col0" class="data row2 col0" >6</td>
#       <td id="T_f6319_row2_col1" class="data row2 col1" >1867</td>
#     </tr>
#     <tr>
#       <td id="T_f6319_row3_col0" class="data row3 col0" >8</td>
#       <td id="T_f6319_row3_col1" class="data row3 col1" >1783</td>
#     </tr>
#     <tr>
#       <td id="T_f6319_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_f6319_row4_col1" class="data row4 col1" >1676</td>
#     </tr>
#     <tr>
#       <td id="T_f6319_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_f6319_row5_col1" class="data row5 col1" >1539</td>
#     </tr>
#     <tr>
#       <td id="T_f6319_row6_col0" class="data row6 col0" >10</td>
#       <td id="T_f6319_row6_col1" class="data row6 col1" >1501</td>
#     </tr>
#     <tr>
#       <td id="T_f6319_row7_col0" class="data row7 col0" >11</td>
#       <td id="T_f6319_row7_col1" class="data row7 col1" >1397</td>
#     </tr>
#     <tr>
#       <td id="T_f6319_row8_col0" class="data row8 col0" >2</td>
#       <td id="T_f6319_row8_col1" class="data row8 col1" >1316</td>
#     </tr>
#     <tr>
#       <td id="T_f6319_row9_col0" class="data row9 col0" >5</td>
#       <td id="T_f6319_row9_col1" class="data row9 col1" >1313</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.pie(data=F.head(10), x='Delayed', labels='Month')
plt.title("Delays(Month)")
plt.show()
